# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# sean@sekora.io
# www.linkedin.com/in/sekora
# (LinkedIn)
# sekora.ai (Company)
# localwhisper.ai (Company)
# Top Skills
# Developer Tooling
# Continuous Integration and
# Continuous Delivery (CI/CD)
# DevEx
# Languages
# English (Native or Bilingual)
# Certifications
# The Data Scientist’s Toolbox
# Developing Innovative Ideas for
# New Companies: The First Step in
# Entrepreneurship
# Advanced Cold Fusion MX 7
# Developer
# Architecting on AWS
# Sean Sekora
# My passion is turning AI from an individual productivity boost into an
# org-wide engineering force multiplier
# Greater Pittsburgh Region
# Summary
# My passion is turning AI from an individual productivity boost into an
# org-wide engineering force multiplier.
# I've spent 24 years building software, nearly a decade of that at
# Smartsheet where I was consistently selected to contribute to the
# highest-stakes technical initiatives: cloud migrations, monolith
# decomposition, platform architecture, and most recently, the
# company's agentic AI strategy alongside principal engineers and the
# VP of Engineering.
# That AI work is where everything clicked for me. I helped evaluate
# and drive adoption of tools like Claude Code and Windsurf, built
# MCP integrations connecting AI to real engineering systems (GitLab,
# Jira, Datadog, PagerDuty, Confluence), and supported adoption
# across the org through hands-on mentorship rather than mandates.
# I saw firsthand what happens when you move from ad-hoc AI
# experimentation to shared workflows, feedback loops, and patterns
# that make every engineer more effective.
# Now I'm focused on this full-time. I'm building LocalWhisper.ai using
# Claude Code as a force multiplier across the entire SDLC, and I'm
# looking for a role where I can help an engineering organization build
# a company-wide AI development ecosystem that empowers teams to
# ship higher quality software, faster and more securely.
# My background is a combination you don't often see together: deep
# platform engineering experience (AWS migrations, microservices,
# orchestration frameworks) plus hands-on AI acceleration work (MCP
# integrations, agentic workflows, adoption strategy). I also have an
# entrepreneurial streak, having co-founded two startups through
# AlphaLab in Pittsburgh.
#   Page 1 of 5
# I'm most energized when I'm figuring out how agentic AI tools and
# practices can elevate engineering teams, and getting engineers
# genuinely excited about integrating them into their day-to-day work.
# Experience
# Smartsheet
# Senior Software Development Engineer II Smartsheet
# July 2016 - Present (9 years 10 months)
# Bellevue, WA
# Selected time and again for foundational engineering initiatives over nearly
# a decade at Smartsheet, spanning monolith decomposition, cloud migration,
# platform framework design, and enterprise AI strategy. Partnered with principal
# engineers, staff-level peers, and VP-level leadership to shape technical
# direction and drive cross-team execution.
# • Co-designed the Solution Orchestrations Service for workspace and
# project provisioning alongside a cross-functional team of senior and principal
# engineers, and currently leading cross-team onboarding of service providers
# into the framework.
# • Selected as part of a senior technical leadership group alongside principal
# engineers and the VP of Engineering to define Smartsheet’s agentic AI
# strategy; led evaluation of Claude Code and Windsurf and established
# workflow standards that reduced the “cold start tax” for codebase onboarding.
# • Built Smartsheet’s Model Context Protocol (MCP) integration from the
# ground up, shipping connectors to the Roo Code Marketplace and Claude and
# positioning Smartsheet as one of the early enterprise platforms to enable AI-
# native workflows through MCP.
# • Led the first service migration from datacenter to AWS as part of
# Project Nimbus, coordinating a cross-functional team spanning database,
# infrastructure, and service engineering.
# • Directed the migration of Smartsheet’s Notification Center from a legacy
# service to a new REST-based architecture, leading a squad of four engineers
# through planning and delivery.
# Qlinary Inc.
# Senior Software Engineer
# April 2014 - July 2016 (2 years 4 months)
# Los Angeles, CA
# Led the architecture, development, and engineering initiatives for a company
# dedicated to intuitive kitchen management software solutions. Entrusted to
#   Page 2 of 5
# identify issues with the existing underperforming product design and created
# effective corrective action plans. Architected a new solution for restaurants to
# efficiently manage operations, products, vendors, recipes, and inventory.
# Environment: Java Play Framework, Ruby on Rails, PostgreSQL, AngularJS,
# Kendo UI, Heroku, Amazon Web Services, and Chef
# * Successfully determined best possible solutions by analyzing and comparing
# various Java frameworks and cloud hosting environments.
# * Proposed/secured executive buy-in for Play framework and Amazon Web
# Services based on business requirements and future scaling.
# * Designed a complex Service Oriented Architecture (SOA) for the application.
# * Directed and led a complete and successful redesign of a large-scale
# restaurant management system.
# * Met all business requirements by researching, designing, and developing a
# custom multi-application security layer.
# * Effectively improved application performance, reliability, and scalability by
# leading the design, setup, and administration of an AWS OpsWorks based
# environment comprised of load balancers, application servers, Apache Solr
# servers, and Postgres servers.
# Philips
# Senior Software Engineer
# January 2014 - April 2014 (4 months)
# Greater Pittsburgh Area
# Serve as a senior software for a company focused on transforming the delivery
# of healthcare solutions.
# Environment: Ruby on Rails 3 and 4, MySQL, TDD using RSpec, BDD using
# Cucumber and Agile with Scrum.
# * Significantly improved code quality and overall performance of their flagship
# medSage product by resolving long-standing bugs.
# * Streamlined the follow-up status processes for patients and customers
# through the successful development and implementation of an internal call
# center phone survey application.
# Modotech
# Programmer | Analyst
# October 2008 - January 2014 (5 years 4 months)
# PA
#   Page 3 of 5
# Contributed to the software development initiatives and served as a pivotal
# technical resource in the development of enterprise software applications for
# property/casualty insurance clientele, from needs assessments through testing
# and implementation.
# Environment: Adobe, ColdFusion, Microsoft SQL, Visual C++
# * Led the architecture and development of a complex insurance verification
# system for Nevada’s Department of Motor Vehicles.
# * Expedited the contract/application processes by implementing e-Signature/
# DocuSign capabilities. Effectively eliminated paperwork and reduced
# turnaround time. Launched a document management system to generate
# customized claim letters/forms in PDF format.
# * Streamlined processes, for end-users, through the design and development
# of a guided application/endorsement user interface.
# * Increased throughput of claim inspections and reporting protocols by driving
# the implementation of an Audatex integrated solution.
# Citynet
# Team Lead & Senior Software Developer
# September 2005 - October 2008 (3 years 2 months)
# WV
# Quickly earned two promotions, due to outstanding work performance, and
# entrusted to lead and manage seven developers. Managed internal enterprise
# applications through the SDLC including purchase ordering, resource
# provisioning, content management, and digital phone administration. Led
# team to develop internal customer facing business applications. Environment:
# ColdFusion, Microsoft SQL
# * Consistently exceeded expectations and earned ‘Employee of the Year’
# honors.
# * Directed and led the architecture, development, and training of an internal
# purchase order system.
# * Trained and mentored development team in object oriented analysis and
# design (OOAD).
# * Developed and implemented high-level coding standards and comprehensive
# peer-based code reviews.
# Literati
# Web Developer
# April 2004 - September 2005 (1 year 6 months)
#   Page 4 of 5
# WV
# National Alternative Fuels Training Consortium
# Assistant IT Specialist
# January 2001 - October 2003 (2 years 10 months)
# WV
# Education
# West Virginia University
# Bachelors Of Science, Computer Engineering · (1997 - 2002)
#   Page 5 of 5

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Sean Sekora"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# 'You are acting as Sean Sekora. You are answering questions on Sean Sekora\'s website, particularly questions related to Sean Sekora\'s career, background, skills and experience. Your responsibility is to represent Sean Sekora for interactions on the website as faithfully as possible. You are given a summary of Sean Sekora\'s background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don\'t know the answer, say so.\n\n## Summary:\nSean Sekora\nsean@sekora.io | linkedin.com/in/sekora | Greater Pittsburgh Region\n\nSUMMARY\nSenior Software Engineer with 20+ years of experience, specializing in platform engineering and\nAI-accelerated developer tooling. Nearly a decade at Smartsheet, consistently selected for the\nhighest-stakes technical initiatives. Deep focus on turning AI from an individual productivity boost\ninto an org-wide engineering force multiplier — through MCP integrations, agentic workflows,\nshared tooling ecosystems, and hands-on adoption work.\n\nEXPERIENCE\n\nSmartsheet — Senior Software Engineer II (Jul 2016 – May 2026, Bellevue WA)\n- Co-designed the Solution Orchestrations Service for workspace and project provisioning;\n  leading cross-team onboarding of service providers into the framework.\n- Selected alongside principal engineers and VP of Engineering to define Smartsheet\'s agentic\n  AI strategy; led evaluation of Claude Code and Windsurf and established workflow standards\n  that reduced the "cold start tax" for codebase onboarding.\n- Built Smartsheet\'s MCP integration from the ground up, shipping connectors to the Roo Code\n  Marketplace and Claude — positioning Smartsheet as an early enterprise MCP adopter.\n- Led the first datacenter-to-AWS service migration as part of Project Nimbus.\n- Directed Notification Center migration from a legacy service to a new REST-based architecture,\n  leading a squad of four engineers.\n\nQlinary Inc. — Senior Software Engineer (Apr 2014 – Jul 2016, Los Angeles CA)\n- Led architecture and development of a large-scale restaurant management platform.\n- Stack: Java Play Framework, Ruby on Rails, PostgreSQL, AngularJS, AWS, Heroku.\n- Designed a complex SOA, secured executive buy-in for Play + AWS, and built a custom\n  multi-application security layer.\n\nPhilips — Senior Software Engineer, Contract (Jan 2014 – Apr 2014, Pittsburgh PA)\n- Ruby on Rails 3/4, MySQL, RSpec/Cucumber TDD/BDD.\n- Resolved long-standing bugs in flagship medSage product; built an internal call center\n  phone survey application.\n\nModotech — Programmer/Analyst (Oct 2008 – Jan 2014, PA)\n- Built enterprise software for property/casualty insurance clients.\n- Led architecture of a complex insurance verification system for Nevada\'s DMV.\n- Stack: ColdFusion, Microsoft SQL, Visual C++.\n\nCitynet — Team Lead & Senior Software Developer (Sep 2005 – Oct 2008, WV)\n- Earned two promotions; led a team of seven developers.\n- Managed enterprise internal apps through full SDLC; earned Employee of the Year.\n- Stack: ColdFusion, Microsoft SQL.\n\nEarlier: Literati — Web Developer (2004–2005); NAFTC/WVU — Assistant IT Specialist (2001–2003)\n\nINDEPENDENT PROJECTS\n\nLocalWhisper.ai — Founder & Creator (Jan 2026 – present)\n- Privacy-first, on-device voice-to-text app built with Flutter, whisper.cpp FFI, Metal GPU\n  acceleration, and a local Qwen3 LLM pipeline. Zero cloud dependency.\n- Using Claude Code as a force multiplier across the full SDLC.\n\nJob Search MCP Server — job-search.sekora.io\n- Personal MCP server exposing job search tooling across Greenhouse, Lever, and Ashby.\n\nENTREPRENEURIAL\n- NoShow Inc., Technical Co-Founder (AlphaLab Pittsburgh)\n- Profile Passer Inc., Technical Co-Founder (AlphaLab Pittsburgh)\n\nSKILLS & TECHNOLOGY\nLanguages:        Java (since 2014), Go, Kotlin, Python, Dart/Flutter, Ruby on Rails, Node.js\nCloud:            AWS, Kuberne ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7866
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# "As of now, I do not hold any patents. My focus has primarily been on software development, AI acceleration, and entrepreneurial ventures, rather than pursuing patents. However, I am passionate about innovation and continually exploring new ideas in the tech space. If you have any questions about specific technologies or projects I've worked on, feel free to ask!"

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The agent accurately answers the question based on the provided context, stating that they do not hold any patents. The response is professional and engaging, aligning with the persona instructions by elaborating on their focus areas and inviting further questions.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply
# Out:
# Failed evaluation - retrying
# The agent's response is in Pig Latin, which is highly unprofessional and does not align with the persona instructions to be professional and engaging, as if talking to a potential client or future employer. The response should have been in plain English.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
